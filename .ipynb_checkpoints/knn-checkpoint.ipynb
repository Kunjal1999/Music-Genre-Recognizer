# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('fma_metadata/features_dataset.csv')

# %%
data.head()
# Out:
#    track_id  chroma_cens_kurtosis  chroma_cens_max  chroma_cens_mean  \
# 0     91062                -0.870            0.473             0.209
# 1     16400                -0.486            0.529             0.270
# 2     52860                 2.060            0.469             0.254
# 3     87236                -0.376            0.556             0.294
# 4     21653                -0.341            0.623             0.224
#
#    chroma_cens_median  chroma_cens_min  chroma_cens_skew  chroma_cens_std  \
# 0               0.213          0.00000           -0.0496           0.1090
# 1               0.262          0.00987            0.1260           0.0995
# 2               0.239          0.02750            1.2400           0.0604
# 3               0.285          0.03490            0.1870           0.0839
# 4               0.213          0.00000            0.4950           0.1420
#
#    chroma_cqt_kurtosis  chroma_cqt_max  ...  tonnetz_skew  tonnetz_std  \
# 0                0.255             1.0  ...       -0.0932       0.0252
# 1               -0.724             1.0  ...       -0.4250       0.0192
# 2               -0.218             1.0  ...       -0.2070       0.0237
# 3               -1.020             1.0  ...        0.2420       0.0233
# 4               -0.672             1.0  ...       -0.5560       0.0355
#
#    zcr_kurtosis  zcr_max  zcr_mean  zcr_median  zcr_min  zcr_skew  zcr_std  \
# 0        49.600    0.351    0.0385      0.0356  0.00928      5.11   0.0188
# 1         0.871    0.247    0.1150      0.1080  0.00000      0.93   0.0313
# 2         7.640    0.241    0.0870      0.0884  0.01760     -0.25   0.0128
# 3         9.530    0.705    0.1530      0.1440  0.01610      1.99   0.0624
# 4        38.100    0.400    0.0444      0.0376  0.00000      4.85   0.0353
#
#    genre_top
# 0          4
# 1         13
# 2          7
# 3          4
# 4         11
#
# [5 rows x 79 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11851 entries, 0 to 11850
# Data columns (total 79 columns):
# track_id                       11851 non-null int64
# chroma_cens_kurtosis           11851 non-null float64
# chroma_cens_max                11851 non-null float64
# chroma_cens_mean               11851 non-null float64
# chroma_cens_median             11851 non-null float64
# chroma_cens_min                11851 non-null float64
# chroma_cens_skew               11851 non-null float64
# chroma_cens_std                11851 non-null float64
# chroma_cqt_kurtosis            11851 non-null float64
# chroma_cqt_max                 11851 non-null float64
# chroma_cqt_mean                11851 non-null float64
# chroma_cqt_median              11851 non-null float64
# chroma_cqt_min                 11851 non-null float64
# chroma_cqt_skew                11851 non-null float64
# chroma_cqt_std                 11851 non-null float64
# chroma_stft_kurtosis           11851 non-null float64
# chroma_stft_max                11851 non-null float64
# chroma_stft_mean               11851 non-null float64
# chroma_stft_median             11851 non-null float64
# chroma_stft_min                11851 non-null float64
# chroma_stft_skew               11851 non-null float64
# chroma_stft_std                11851 non-null float64
# mfcc_kurtosis                  11851 non-null float64
# mfcc_max                       11851 non-null float64
# mfcc_mean                      11851 non-null float64
# mfcc_median                    11851 non-null float64
# mfcc_min                       11851 non-null float64
# mfcc_skew                      11851 non-null float64
# mfcc_std                       11851 non-null float64
# rmse_kurtosis                  11851 non-null float64
# rmse_max                       11851 non-null float64
# rmse_mean                      11851 non-null float64
# rmse_median                    11851 non-null float64
# rmse_min                       11851 non-null float64
# rmse_skew                      11851 non-null float64
# rmse_std                       11851 non-null float64
# spectral_bandwidth_kurtosis    11851 non-null float64
# spectral_bandwidth_max         11851 non-null float64
# spectral_bandwidth_mean        11851 non-null float64
# spectral_bandwidth_median      11851 non-null float64
# spectral_bandwidth_min         11851 non-null float64
# spectral_bandwidth_skew        11851 non-null float64
# spectral_bandwidth_std         11851 non-null float64
# spectral_centroid_kurtosis     11851 non-null float64
# spectral_centroid_max          11851 non-null float64
# spectral_centroid_mean         11851 non-null float64
# spectral_centroid_median       11851 non-null float64
# spectral_centroid_min          11851 non-null float64
# spectral_centroid_skew         11851 non-null float64
# spectral_centroid_std          11851 non-null float64
# spectral_contrast_kurtosis     11851 non-null float64
# spectral_contrast_max          11851 non-null float64
# spectral_contrast_mean         11851 non-null float64
# spectral_contrast_median       11851 non-null float64
# spectral_contrast_min          11851 non-null float64
# spectral_contrast_skew         11851 non-null float64
# spectral_contrast_std          11851 non-null float64
# spectral_rolloff_kurtosis      11851 non-null float64
# spectral_rolloff_max           11851 non-null float64
# spectral_rolloff_mean          11851 non-null float64
# spectral_rolloff_median        11851 non-null float64
# spectral_rolloff_min           11851 non-null float64
# spectral_rolloff_skew          11851 non-null float64
# spectral_rolloff_std           11851 non-null float64
# tonnetz_kurtosis               11851 non-null float64
# tonnetz_max                    11851 non-null float64
# tonnetz_mean                   11851 non-null float64
# tonnetz_median                 11851 non-null float64
# tonnetz_min                    11851 non-null float64
# tonnetz_skew                   11851 non-null float64
# tonnetz_std                    11851 non-null float64
# zcr_kurtosis                   11851 non-null float64
# zcr_max                        11851 non-null float64
# zcr_mean                       11851 non-null float64
# zcr_median                     11851 non-null float64
# zcr_min                        11851 non-null float64
# zcr_skew                       11851 non-null float64
# zcr_std                        11851 non-null float64
# genre_top                      11851 non-null int64
# dtypes: float64(77), int64(2)
# memory usage: 7.1 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.preprocessing import StandardScaler

# %%
df2 = data.drop(['track_id','genre_top'],axis=1)

# %%
scaler = StandardScaler(copy=False)
scaler.fit(df2)
df2 = pd.DataFrame(scaler.transform(df2),columns=df2.columns)

# %%
X = df2
y = data['genre_top']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.head()
# Out:
#       chroma_cens_kurtosis  chroma_cens_max  chroma_cens_mean  \
# 7400             -0.362496        -0.726698          0.623878
# 7514             -0.024896         1.194725          1.383131
# 2807              0.847327         1.146387          4.340219
# 5880             -0.176908        -0.303743          2.035821
# 67               -0.469863        -0.775035         -1.214312
#
#       chroma_cens_median  chroma_cens_min  chroma_cens_skew  chroma_cens_std  \
# 7400            0.607827        -0.297194         -0.595397        -0.370012
# 7514            1.342777         0.524295         -0.757330        -0.758591
# 2807            3.938066         3.940642         -2.248121        -1.330667
# 5880            1.744702         5.994363          0.075710        -1.004152
# 67             -1.321415        -0.297194          0.473031         0.574452
#
#       chroma_cqt_kurtosis  chroma_cqt_max  chroma_cqt_mean  ...  tonnetz_min  \
# 7400            -0.074993        0.022575         0.824493  ...     0.610794
# 7514            -0.089850        0.022575         0.531693  ...    -3.847811
# 2807             2.938859        0.022575         3.482808  ...     0.784135
# 5880            -0.058500        0.022575         1.571903  ...     0.836796
# 67               0.011834        0.022575        -1.340685  ...     0.057857
#
#       tonnetz_skew  tonnetz_std  zcr_kurtosis   zcr_max  zcr_mean  zcr_median  \
# 7400     -0.279065    -0.250789     -0.244533 -0.383905  0.683237    0.833242
# 7514     -2.631537     0.055316     -0.106142 -0.383905  0.242846    0.438871
# 2807     -0.730912    -0.505877      1.551513 -0.094864 -1.125180   -0.904555
# 5880      0.396912    -0.238035     -0.033411 -1.000896 -1.331321   -1.203379
# 67        0.963513     0.310404      0.249430  2.373101 -0.163189   -0.420409
#
#        zcr_min  zcr_skew   zcr_std
# 7400 -0.451918 -0.707080 -0.265536
# 7514 -0.451918 -0.253065 -0.638970
# 2807 -0.451918  3.708021 -0.627767
# 5880 -0.451918  0.222976 -0.993733
# 67    0.276218  1.416631  1.777147
#
# [5 rows x 77 columns]

# %%
error_rates = list()
for i in range(1,40):
    print("K =",i)
    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    preds = knn.predict(X_test)
    error_rates.append(np.mean(y_test!=preds))
# Out:
# K = 1
# K = 2
# K = 3
# K = 4
# K = 5
# K = 6
# K = 7
# K = 8
# K = 9
# K = 10
# K = 11
# K = 12
# K = 13
# K = 14
# K = 15
# K = 16
# K = 17
# K = 18
# K = 19
# K = 20
# K = 21
# K = 22
# K = 23
# K = 24
# K = 25
# K = 26
# K = 27
# K = 28
# K = 29
# K = 30
# K = 31
# K = 32
# K = 33
# K = 34
# K = 35
# K = 36
# K = 37
# K = 38
# K = 39

# %%
plt.figure(figsize=(12,6))
plt.xlabel('K values')
plt.ylabel('Error rates')
plt.title('Error rates vs K values')
plt.plot(range(1,40),error_rates,marker='o',markersize=8,markerfacecolor='red')

# %%
knn = KNeighborsClassifier(7)
knn.fit(X_train,y_train)
knn_preds = knn.predict(X_test)

# %%
print(classification_report(y_test,knn_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29         5
#            1       0.29      0.53      0.37        15
#            2       0.35      0.44      0.39       153
#            3       0.15      0.19      0.17        32
#            4       0.59      0.63      0.61       519
#            5       0.59      0.80      0.68       643
#            6       0.60      0.37      0.46        71
#            7       0.60      0.40      0.48       474
#            8       0.29      0.11      0.16        55
#            9       0.79      0.79      0.79       107
#           10       0.41      0.28      0.33       110
#           11       0.31      0.09      0.14       113
#           12       1.00      0.40      0.57         5
#           13       0.78      0.92      0.84        59
#           14       0.00      0.00      0.00        10
#
#     accuracy                           0.56      2371
#    macro avg       0.48      0.41      0.42      2371
# weighted avg       0.55      0.56      0.54      2371
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Summary
#
# Dataset size - 11851 rows x 79 columns
#
#
# ## Splitting the dataset 70:30 train test split ratio
#
# * Best K value for KNN is 9 which gives accuracy of 55%
#
#
# ## Splitting the dataset 80:20 train test split ratio
#
# * Best K value for KNN is 9 which gives accuracy of 56%
